# %%
import usaddress
import pandas as pd
from sqlalchemy import create_engine

# %%
usaddress.parse('300 St Joseph Parkway #318, Houston, TX 77002')
# Out:
# [('300', 'AddressNumber'),
#  ('St', 'StreetName'),
#  ('Joseph', 'StreetName'),
#  ('Parkway', 'StreetNamePostType'),
#  ('#', 'OccupancyIdentifier'),
#  ('318,', 'OccupancyIdentifier'),
#  ('Houston,', 'PlaceName'),
#  ('TX', 'StateName'),
#  ('77002', 'ZipCode')]

# %%
# Load har data to a dataframe
har = pd.read_csv('har_data.csv')
har_df = pd.DataFrame(har)
har_df.head(50)
# Out:
#          mls                                         address  bld_sft  \
# 0   17777272  1211 Caroline Street PH2002, Houston, TX 77002   2433.0
# 1   54714244   1211 Caroline Street #1903, Houston, TX 77002   2579.0
# 2    8077568       915 Franklin Street 9F, Houston, TX 77002   2380.0
# 3   43392628     2000 Bagby Street #15400, Houston, TX 77002   2359.0
# 4   64069960       1211 Caroline st #1105, Houston, TX 77002   1235.0
# 5   33083163   1211 Caroline Street #1005, Houston, TX 77002   1235.0
# 6   86715428        914 Main Street #2204, Houston, TX 77002   2890.0
# 7   88139730        919 Prairie Street 2A, Houston, TX 77002   1332.0
# 8   29849105   1211 Caroline Street #1201, Houston, TX 77002   1393.0
# 9   41861910    1211 Caroline Street #804, Houston, TX 77002    975.0
# 10  54475080  204 Travis Street Street 4E, Houston, TX 77002   1868.0
# 11  64170091    1211 Caroline Street #902, Houston, TX 77002   1122.0
# ...

# %%
import pandas_usaddress

#load dataframe
#df1=pd.DataFrame(har_df['address'])

#initiate usaddress
df = pandas_usaddress.tag(har_df, ['address'])

#send output to csv
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_usaddress\__init__.py:94: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['odictaddress'] = df['odictaddress'].str.replace('[^\w\s\-]','')
#         mls                                         address  bld_sft  lot_sft  \
# 0  17777272  1211 Caroline Street PH2002, Houston, TX 77002   2433.0      0.0
# 1  54714244   1211 Caroline Street #1903, Houston, TX 77002   2579.0      0.0
# 2   8077568       915 Franklin Street 9F, Houston, TX 77002   2380.0      0.0
# 3  43392628     2000 Bagby Street #15400, Houston, TX 77002   2359.0      0.0
# 4  64069960       1211 Caroline st #1105, Houston, TX 77002   1235.0      0.0
#
#        price    zip AddressNumber AddressNumberPrefix AddressNumberSuffix  \
# 0  1745000.0  77002          1211                 NaN                 NaN
# 1  1490000.0  77002          1211                 NaN                 NaN
# ...

# %%
df.columns
# Out:
# Index(['mls', 'address', 'bld_sft', 'lot_sft', 'price', 'zip', 'AddressNumber',
#        'AddressNumberPrefix', 'AddressNumberSuffix', 'BuildingName',
#        'CornerOf', 'IntersectionSeparator', 'LandmarkName', 'NotAddress',
#        'OccupancyType', 'OccupancyIdentifier', 'PlaceName', 'Recipient',
#        'StateName', 'StreetName', 'StreetNamePreDirectional',
#        'StreetNamePreModifier', 'StreetNamePreType',
#        'StreetNamePostDirectional', 'StreetNamePostModifier',
#        'StreetNamePostType', 'SubaddressIdentifier', 'SubaddressType',
#        'USPSBoxGroupID', 'USPSBoxGroupType', 'USPSBoxID', 'USPSBoxType',
#        'ZipCode'],
#       dtype='object')

# %%
df['OccupancyIdentifier']
# Out:
# 0        ph2002
# 1          1903
# 2            9f
# 3         15400
# 4          1105
#           ...
# 18310      1206
# 18311      2403
# 18312       180
# 18313       150
# 18314       NaN
# Name: OccupancyIdentifier, Length: 18315, dtype: object

# %%
df['address']
# Out:
# 0           1211 Caroline Street PH2002, Houston, TX 77002
# 1            1211 Caroline Street #1903, Houston, TX 77002
# 2                915 Franklin Street 9F, Houston, TX 77002
# 3              2000 Bagby Street #15400, Houston, TX 77002
# 4                1211 Caroline st #1105, Houston, TX 77002
#                                ...
# 18310     260 El Dorado Boulevard #1206, Webster, TX 77598
# 18311     260 El Dorado Boulevard #2403, Houston, TX 77598
# 18312      250 El Dorado Boulevard #180, Webster, TX 77598
# 18313      250 El Dorado Boulevard #150, Houston, TX 77598
# 18314    250 El Dorado Building L Boulevard #201, Webst...
# Name: address, Length: 18315, dtype: object

# %%
SELECT id, name, pet_name, pet_age
FROM people
WHERE name = 'Dave';

# %%
engine = create_engine('postgresql://postgres:postgress@localhost:5432/Houston_real_estate')

# %%
df_test=pd.read_sql("SELECT * FROM real_acct WHERE str='EL DORADO' AND str_num='250' and str_unit='123'", engine)

# %%
df_test
# Out:
#                         acct  str_num str_num_sfx        str str_sfx  \
# 0  1143370030007                250.0              EL DORADO    BLVD
#
#   str_sfx_dir str_unit             site_addr_1 site_addr_2 site_addr_3  \
# 0                  123  250 EL DORADO BLVD 123     WEBSTER       77598
#
#    bld_ar  land_ar  tot_appr_val  tot_mkt_val
# 0   964.0      0.0       78184.0      78184.0

# %%
df_test1=pd.read_sql("SELECT address, occupancyidentifier, streetname FROM har_address WHERE streetname='austin' and addressnumber='2225' ", engine)
df_test1
# Out:
#                                  address occupancyidentifier streetname
# 0  2225 AUSTIN Street, Houston, TX 77002                None     austin

# %%
pd.read_sql("SELECT * FROM real_acct WHERE str='AUSTIN' AND str_num='2225'", engine)
# Out:
#                         acct str_num str_num_sfx     str str_sfx str_sfx_dir  \
# 0  1371720010001                2225              AUSTIN      ST
#
#   str_unit     site_addr_1 site_addr_2 site_addr_3  bld_ar  land_ar  \
# 0           2225 AUSTIN ST     HOUSTON       77002     0.0   4996.0
#
#    tot_appr_val  tot_mkt_val
# 0      324740.0     324740.0

# %%
pd.read_sql("SELECT streetname FROM har_address", engine).head(2)
# Out:
#   streetname
# 0   caroline
# 1   caroline

# %%
har
# Out:
#             mls                                            address  bld_sft  \
# 0      17777272     1211 Caroline Street PH2002, Houston, TX 77002   2433.0
# 1      54714244      1211 Caroline Street #1903, Houston, TX 77002   2579.0
# 2       8077568          915 Franklin Street 9F, Houston, TX 77002   2380.0
# 3      43392628        2000 Bagby Street #15400, Houston, TX 77002   2359.0
# 4      64069960          1211 Caroline st #1105, Houston, TX 77002   1235.0
# ...         ...                                                ...      ...
# 18310  74764744   260 El Dorado Boulevard #1206, Webster, TX 77598    691.0
# 18311  57653779   260 El Dorado Boulevard #2403, Houston, TX 77598    756.0
# 18312  11376196    250 El Dorado Boulevard #180, Webster, TX 77598    604.0
# 18313  72921661    250 El Dorado Boulevard #150, Houston, TX 77598    693.0
# 18314  26728470  250 El Dorado Building L Boulevard #201, Webst...    648.0
#
#         lot_sft      price    zip
# ...
